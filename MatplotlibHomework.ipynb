# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# File to Load (Remember to change these)
ride_data_to_load = "data/ride_data.csv"
city_data_to_load = "data/city_data.csv"


# Read the City and Ride Data
ride_data = pd.read_csv(ride_data_to_load)
city_data = pd.read_csv(city_data_to_load)

# Combine the data into a single dataset
fares = ride_data.groupby('city')['fare'].sum()
rides = ride_data.groupby('city')['city'].count()
avg = fares / rides
merge_table = pd.merge(city_data, pd.DataFrame({'avgfare':avg, 'rides':rides, 'fares':fares}).reset_index(), on="city")

#check DF
city_data.head()

# Display the data table for preview
merge_table.head(100)
# Out:
#                     city  driver_count      type    avgfare  rides    fares
# 0            Richardfort            38     Urban  22.373214     28   626.45
# 1           Williamsstad            59     Urban  24.362174     23   560.33
# 2            Port Angela            67     Urban  23.836842     19   452.90
# 3             Rodneyfort            34     Urban  28.616957     23   658.19
# 4            West Robert            39     Urban  25.123871     31   778.84
# 5           West Anthony            70     Urban  24.736667     30   742.10
# 6            West Angela            48     Urban  25.990000     39  1013.61
# 7          Martinezhaven            25     Urban  22.651250     24   543.63
# 8              Karenberg            22     Urban  26.340000     17   447.78
# 9            Barajasview            26     Urban  25.332273     22   557.31
# 10            Robertport            12     Urban  23.060500     20   461.21
# 11          Joneschester            39     Urban  22.289600     25   557.24
# 12               Leahton            17     Urban  21.243810     21   446.12
# 13  West Christopherberg            32     Urban  24.421154     26   634.95
# 14               Johnton            27     Urban  26.785714     21   562.50
# 15          Reynoldsfurt            67     Urban  21.919474     19   416.47
# 16            Port David             7     Urban  25.855000     22   568.81
# 17   New Kimberlyborough            33     Urban  22.589000     30   677.67
# 18           Carriemouth            52     Urban  28.314444     27   764.49
# 19             Rogerston            25     Urban  22.097727     22   486.15
# 20              Jerryton            64     Urban  25.649200     25   641.23
# 21             Loganberg            23     Urban  25.292500     28   708.19
# 22          Simpsonburgh            21     Urban  23.355833     24   560.54
# 23            Port Frank            23     Urban  27.201515     33   897.65
# 24          South Latoya            10     Urban  20.093158     19   381.77
# 25      West Samuelburgh            73     Urban  21.767600     25   544.19
# 26           Grahamburgh            61     Urban  25.221200     25   630.53
# 27   West Patrickchester            25     Urban  28.233125     16   451.73
# 28        North Madeline            19     Urban  22.623600     25   565.59
# 29            South Jack            46     Urban  22.965263     19   436.34
# ..                   ...           ...       ...        ...    ...      ...
# 70           New Raymond            17  Suburban  27.961818     22   615.16
# 71          South Teresa            21  Suburban  31.220455     22   686.85
# 72            Myersshire            19  Suburban  30.203125     16   483.25
# 73             Grayville             2  Suburban  27.763333     15   416.45
# 74       Lake Robertside             4  Suburban  31.262000     25   781.55
# 75            Lewishaven            23  Suburban  25.241667     12   302.90
# 76         Rodriguezview            20  Suburban  30.745333     15   461.18
# 77          Victoriaport            16  Suburban  27.780000     14   388.92
# 78       Williamsonville             2  Suburban  31.875000     14   446.25
# 79           West Hannah            12  Suburban  29.547619     21   620.50
# 80         West Kimmouth             4  Suburban  29.871500     20   597.43
# 81       New Shannonberg            20  Suburban  28.378235     17   482.43
# 82         North Timothy             7  Suburban  31.262000     15   468.93
# 83            New Olivia            20  Suburban  34.054118     17   578.92
# 84             Lake Omar            22  Suburban  28.075000     14   393.05
# 85             Sotoville            10  Suburban  31.980000     11   351.78
# 86          Veronicaberg            20  Suburban  32.828235     17   558.08
# 87         East Kentstad            20  Suburban  29.823077     13   387.70
# 88           Bethanyland            22  Suburban  32.956111     18   593.21
# 89          South Brenda             1  Suburban  33.964583     24   815.15
# 90         Barronchester            11  Suburban  36.422500     16   582.76
# 91           Brandonfort            10  Suburban  35.437368     19   673.31
# 92       East Danielview            22  Suburban  31.560588     17   536.53
# 93        East Marymouth             5  Suburban  30.835185     27   832.55
# 94           Mezachester            14  Suburban  30.760000     17   522.92
# 95             Lewisland             4  Suburban  34.614118     17   588.44
# 96            Josephside            25  Suburban  32.858148     27   887.17
# 97             Davidfurt            23  Suburban  31.995882     17   543.93
# 98         Nicolechester            19  Suburban  30.909474     19   587.28
# 99        East Aaronbury             7  Suburban  25.661111      9   230.95
#
# [100 rows x 6 columns]

# %%
ride_data.head()
# Out:
#                  city                 date   fare        ride_id
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2018-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2018-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2018-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2018-03-06 04:28:35  34.58  3908451377344

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
# Obtain the x and y coordinates for each of the three city types

# x, Urban
x_urban = merge_table[merge_table.type=='Urban'] ['fares']
#print(x_urban)

y_urban = merge_table[merge_table.type=='Urban'] ['avgfare']
#print(x_urban)


# x, Suburban
x_Suburban = merge_table[merge_table.type=='Suburban'] ['fares']
#print(x_urban)

y_Suburban = merge_table[merge_table.type=='Suburban'] ['avgfare']
#print(x_urban)

# x, Rural
x_Rural = merge_table[merge_table.type=='Rural'] ['fares']
#print(x_urban)

y_Rural = merge_table[merge_table.type=='Rural'] ['avgfare']
#print(x_urban)


# Build the scatter plots for each city types
plt.scatter(x_urban, y_urban, marker="o", facecolors="coral", edgecolors="black",
            s=x_urban, alpha=0.87)

plt.scatter(x_Suburban, y_Suburban, marker="o", facecolors="skyblue", edgecolors="black",
            s=x_Suburban, alpha=0.87)

plt.scatter(x_Rural, y_Rural, marker="o", facecolors="yellow", edgecolors="black",
            s=x_Rural, alpha=0.87)

colors = {"Urban":"coral", "Rural":"yellow","Suburban":"skyblue"}
city_labels = ["Urban", "Rural", "Suburban"]
legend_color = ["lightblue", "yellow","coral"]

# Incorporate the other graph properties
plt.grid(axis='both')
plt.title("Pyber Ride Sharing Data (2016)")
plt.xlabel("Total Number of Rides (Per City)")
plt.ylabel("Average Fare ($)")

# Create a legend

# Save Figure
# Out:
# Text(0, 0.5, 'Average Fare ($)')

# %%
fig_Pyber_Ride_Sharing = plt.figure(1,figsize=(10,20))

# %%
# Show plot
plt.show()

# %% [markdown]
# ## Total Fares by City Type

# %%
# Calculate Type Percents
type_dataframe = merge_table.groupby(["type"]) 
total_rides_per_type = type_dataframe["city"].count()
print(total_rides_per_type[0])
print(total_rides_per_type)

# Build Pie Chart
labels = ["Rural", "Suburban", "Urban"]

# Labels for the sections of our pie chart
labels = ["Rural", "Suburban", "Urban"]

# The values of each section of the pie chart
sizes = [tot_driver_per_type[0], tot_driver_per_type[1], tot_driver_per_type[2]]

# The colors of each section of the pie chart
colors = ["yellow", "lightblue", "coral"]

# Tells matplotlib to seperate the "Python" section from the others
explode = (0, 0, 0.1)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%3.1f%%", shadow=True, startangle=120)

plt.title("% Total Driver Count by City Type")

# Save Figure
plt.savefig("driver.png")

# Show Figure
plt.show()
# Out:
# 18
# type
# Rural       18
# Suburban    36
# Urban       66
# Name: city, dtype: int64

# %%
# Save Figure
plt.savefig("Ride.png")

# %% [markdown]
# ## Total Rides by City Type

# %%
# Calculate Ride Percents
type_dataframe = merge_table.groupby(["type"]) 
total_driver_per_type = type_dataframe["driver_count"].sum()
print(total_driver_per_type[0])
print(total_driver_per_type)

# Build Pie Chart
labels = ["Rural", "Suburban", "Urban"]

# Save Figure
plt.savefig("drive.png")

# Show Figure
plt.show()
# Out:
# 78
# type
# Rural         78
# Suburban     490
# Urban       2405
# Name: driver_count, dtype: int64

# %% [markdown]
# ## Total Drivers by City Type

# %%
# Calculate Driver Percents
type_df = merge_table.groupby(["type"]) 
tot_driver_per_type = type_df["driver_count"].sum()
print(tot_driver_per_type[0])
print(tot_driver_per_type)

# Build Pie Charts

# Labels for the sections of our pie chart
labels = ["Rural", "Suburban", "Urban"]

# The values of each section of the pie chart
sizes = [tot_driver_per_type[0], tot_driver_per_type[1], tot_driver_per_type[2]]

# The colors of each section of the pie chart
colors = ["yellow", "lightblue", "coral"]

# Tells matplotlib to seperate the "Python" section from the others
explode = (0, 0, 0.1)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct="%2.1f%%", shadow=True, startangle=120)

plt.title("% Total Driver Count by City Type")

# Save Figure
plt.savefig("driver.png")

# Show Figure
plt.show()
# Out:
# 78
# type
# Rural         78
# Suburban     490
# Urban       2405
# Name: driver_count, dtype: int64

# %%
# Show Figure
plt.show()
